# %% [markdown]
# # Objective: analysis 20 bacteria

# %% [raw]
# Objective
# ---------
# 1) Perform CCA
# 2) Perform Jacard

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import copy

# %% [markdown]
# ## 0) Loading files

# %%
# Set working directory
# %cd "D:\univ\2014-2015\thesis\KERMIT\bacterial similarity\data mining
# Out:
# D:\univ\2014-2015\thesis\KERMIT\bacterial similarity\data mining

# %%
# Define data locations
loc_rhizobium ="data_organism_reactions/Stoichiometric Matrices/394.7.txt"
loc_agro ="data_organism_reactions/Stoichiometric Matrices/176299.3.txt"
loc_burkho ="data_organism_reactions/Stoichiometric Matrices/269483.3.txt"
loc_para ="data_organism_reactions/Stoichiometric Matrices/318586.5.txt"
loc_bacillus ="data_organism_reactions/Stoichiometric Matrices/388400.4.txt"

loc_vibrio = "data_organism_reactions/Stoichiometric Matrices/417398.15.txt"
loc_glucono = "data_organism_reactions/Stoichiometric Matrices/290633.1.txt"
loc_acineto = "data_organism_reactions/Stoichiometric Matrices/575565.3.txt"
loc_desulfo = "data_organism_reactions/Stoichiometric Matrices/207559.7.txt"
loc_caldi = "data_organism_reactions/Stoichiometric Matrices/768670.3.txt"
loc_soda = "data_organism_reactions/Stoichiometric Matrices/343509.12.txt"
loc_gardner = "data_organism_reactions/Stoichiometric Matrices/682147.3.txt"
loc_anthracis = "data_organism_reactions/Stoichiometric Matrices/592021.13.txt"
loc_rhodo1 = "data_organism_reactions/Stoichiometric Matrices/467661.3.txt"
loc_deino = "data_organism_reactions/Stoichiometric Matrices/319795.16.txt"
loc_cereus = "data_organism_reactions/Stoichiometric Matrices/526977.3.txt"
loc_flavo = "data_organism_reactions/Stoichiometric Matrices/313603.3.txt"
loc_rhodo2 = "data_organism_reactions/Stoichiometric Matrices/367336.3.txt"
loc_lacto = "data_organism_reactions/Stoichiometric Matrices/220668.9.txt"
loc_termite = "data_organism_reactions/Stoichiometric Matrices/471821.5.txt"

# 417398.15	Vibrio cholerae MZO-2	18
# 290633.1	Gluconobacter oxydans 621H	1	
# 575565.3	Acinetobacter sp. SH024	28
# 207559.7	Desulfovibrio desulfuricans subsp. desulfuricans str. G20	18
# 768670.3	Calditerrivibrio nitroreducens DSM 19672	1
# 343509.12	Sodalis glossinidius str. 'morsitans'	1
# 682147.3	Gardnerella vaginalis AMD	1
# 592021.13	Bacillus anthracis str. A0248	74
# 467661.3	Rhodobacteraceae bacterium KLH11	13
# 319795.16	Deinococcus geothermalis DSM 11300	10
# 526977.3	Bacillus cereus ATCC 4342	74
# 313603.3	Flavobacteriales bacterium HTCC2170	2
# 367336.3	Rhodobacterales bacterium HTCC2255	2
# 220668.9	Lactobacillus plantarum WCFS1	25
# 471821.5	uncultured Termite group 1 bacterium phylotype Rs-D17	107

# %%
df_rhizobium = pd.read_csv(loc_rhizobium, index_col=0)
df_agro = pd.read_csv(loc_agro, index_col=0)
df_burkho = pd.read_csv(loc_burkho, index_col=0)
df_para = pd.read_csv(loc_para, index_col=0)
df_bacillus = pd.read_csv(loc_bacillus, index_col=0)

df_vibrio = pd.read_csv(loc_vibrio, index_col=0)
df_glucono = pd.read_csv(loc_glucono, index_col=0)
df_acineto = pd.read_csv(loc_acineto, index_col=0)
df_desulfo = pd.read_csv(loc_desulfo, index_col=0)
df_caldi = pd.read_csv(loc_caldi, index_col=0)
df_soda = pd.read_csv(loc_soda, index_col=0)
df_gardner = pd.read_csv(loc_gardner, index_col=0)
df_anthracis = pd.read_csv(loc_anthracis, index_col=0)
df_rhodo1 = pd.read_csv(loc_rhodo1, index_col=0)
df_deino = pd.read_csv(loc_deino, index_col=0)
df_cereus = pd.read_csv(loc_cereus, index_col=0)
df_flavo = pd.read_csv(loc_flavo, index_col=0)
df_rhodo2 = pd.read_csv(loc_rhodo2, index_col=0)
df_lacto = pd.read_csv(loc_lacto, index_col=0)
df_termite = pd.read_csv(loc_termite, index_col=0)

# %%
df_rhizobium = pd.read_csv(loc_rhizobium, index_col=0)

# %%
# Load database for compounds and reactions
loc_compound_db = "data_preprocessing/ModelSEED-compounds-db.csv"
loc_reaction_db = "data_preprocessing/ModelSEED-reactions-db.csv"
df_compound = pd.read_csv(loc_compound_db)
df_reaction= pd.read_csv(loc_reaction_db)

# %%
# Define function to look up compound code in DATABASE and return a list with abbreviated compound names
def switch_compounds(list_compounds):
    """
    Look up compounds in database and return a list of comprehensible compound names
    """
    return [df_compound.loc[df_compound.DATABASE == compound].ABBREVIATION.values[0] for compound in list_compounds]

# %%
# trivially define your stoichiometric matrices
S_rhizobium  = df_rhizobium 
S_agro  = df_agro 
S_burkho  = df_burkho 
S_para = df_para
S_bacillus = df_bacillus

S_vibrio  = df_vibrio 
S_glucono = df_glucono
S_acineto = df_acineto
S_desulfo = df_desulfo
S_caldi  = df_caldi 
S_soda  = df_soda 
S_gardner = df_gardner
S_anthracis  = df_anthracis 
S_rhodo1  = df_rhodo1 
S_deino  = df_deino 
S_cereus = df_cereus
S_flavo  = df_flavo 
S_rhodo2  = df_rhodo2 
S_lacto  = df_lacto 
S_termite = df_termite

# %%
scope = globals().keys()
S = [SM for SM in scope if "S_" in SM]
S = [SM for SM in S if isinstance(eval(SM), pd.DataFrame)]
S
# Out:
# ['S_rhodo1',
#  'S_lacto',
#  'S_termite',
#  'S_rhodo2',
#  'S_deino',
#  'S_anthracis',
#  'S_bacillus',
#  'S_flavo',
#  'S_glucono',
#  'S_acineto',
#  'S_cereus',
#  'S_soda',
#  'S_vibrio',
#  'S_caldi',
#  'S_gardner',
#  'S_burkho',
#  'S_para',
#  'S_rhizobium',
#  'S_desulfo',
#  'S_agro']

# %% [markdown]
# ## 1) Canonical Correlation Analysis

# %%
def create_frames(S1, S2):
    """
    @param S1: accepts stoichiometric matrix 1
    @param S2: accepts stoichiometric matrix 2
    @return: returns two stoichiometric matrices where the rows:
            * consist of the same compounds
            * are sorted according to the index
    """
    # Determine which compounds to add
    cp_add_1 = S2.index[~S2.index.isin(S1.index)] # Find compounds not present in S1
    cp_add_2 = S1.index[~S1.index.isin(S2.index)] # Find compounds not present in S2
    
    # Create matrix you want to append
    append1 = np.zeros([len(cp_add_1), S1.shape[1]]) # Create matrix to append matrix1
    append2 = np.zeros([len(cp_add_2), S2.shape[1]]) # Create matrix to append matrix2
    
    # Create frames to return
    frame1 = S1.append(pd.DataFrame(append1, columns = S1.columns, index = cp_add_1))
    frame2 = S2.append(pd.DataFrame(append2, columns = S2.columns, index = cp_add_2))

    # Sort rowwise
    frame1 = frame1.sort_index()
    frame2 = frame2.sort_index()
    
    return frame1, frame2

def CCA(S1, S2):
    """
    @param S1: accepts stoichiometric matrix 1
    @param S2: accepts stoichiometric matrix 2
    @return: returns the lambda value of the canonical correlation analysis (CCA)
    
    CCA
    ---
    formula:
    [ (S1^T * S1 + I * lambda)^-1 * (S1^T * S2) * (S2^T * S2 + I * lambda)^-1 ] * (S2^T * S1) a = lambda^2 * a 
    
    implementation:
    term1 = (S1^T * S1 + I * lambda)^-1 
    term2 = (S1^T * S2)
    term3 = (S2^T * S2 + I * lambda)^-1 
    term4 = (S2^T * S1)
    lambda is a measure of correlation between two stoichiometric matrices
    
    """
    # Create matrices with the same compounds
    S1, S2 = create_frames(S1, S2)
      
    # Calculate CCA-measure
    r1 = S1.shape[1]
    r2 = S2.shape[1]
    
    cov = np.cov(S1, S2, rowvar = 0)
    allr = r1 + r2
    
    Sxx = cov[0:r1, 0:r1]
    Syy = cov[r1:allr, r1:allr]
    Sxy = cov[0:r1, r1:allr]
    Syx = cov[r1:allr, 0:r1]
    
    # Calculate CCA-measure
    Sxx = np.linalg.inv(Sxx + np.eye(r1) * .001)
    Syy = np.linalg.inv(Syy + np.eye(r2) * .001)
    
    # lambda_square = np.dot(term1, term2)
    # lambda_square = np.dot(lambda_square, term3)
    # lambda_square = np.dot(lambda_square, term4)
    lambda_square = reduce(np.dot, [Sxx, Sxy, Syy, Syx])
    #lambda_square = np.around(lambda_square, decimals = 3)
    # return np.sqrt(max(real(np.linalg.eig(lambda_square)[0])))
    return np.trace(lambda_square)


def CCA_matrix(list_of_S):
    """
    @param list_of_S: accepts a list of Stoichiometric Matrices
    @return: returns a pd.DataFrame with all lambda values corresponding lambda values
    """
    n = len(list_of_S)
    df_CF = np.zeros([n, n])
    for i in xrange(n):
        for j in xrange(i + 1):
            S1 = eval(list_of_S[i])
            S2 = eval(list_of_S[j])
            df_CF[i,j] = CCA(S1, S2)
    for i in xrange(n):
        for j in xrange(n - 1 - i):
            df_CF[i, j + 1 + i] = df_CF[j + 1 + i, i]  
       
    return pd.DataFrame(df_CF, columns= list_of_S, index = list_of_S)

# %%
a = CCA_matrix(S)

# %%
a
# Out:
#                S_rhodo1     S_lacto   S_termite    S_rhodo2     S_deino  \
# S_rhodo1     439.443122  324.970112  275.564982  342.120544  356.716431
# S_lacto      324.970112  417.369315  264.860089  282.516967  328.227126
# S_termite    275.564982  264.860089  345.810047  247.239274  263.212215
# S_rhodo2     342.120544  282.516967  247.239274  447.131273  311.815849
# S_deino      356.716431  328.227126  263.212215  311.815849  429.041725
# S_anthracis  352.233223  330.268467  256.139644  333.674980  335.850605
# S_bacillus   355.100492  325.821284  263.870226  316.763782  340.643945
# S_lacto       825.184752   801.707740   827.016289   740.946854   830.413466
# S_termite     668.417645   667.973118   667.715559   657.734714   662.603733
# S_rhodo2      876.643945   888.862899   922.440142   826.549027   923.157190
# S_deino       894.199385   859.283172   884.260547   756.358727   886.899093
# S_anthracis   992.789996   970.551284   991.091946   883.192102  1012.535791
# S_bacillus    960.338407   933.528907   965.689902   865.263547   988.193928
# S_flavo       933.134318   903.476008   963.160598   840.487113   953.182628
# S_glucono     770.865220   762.723130   777.371623   746.955365   791.385498
# S_acineto     965.389419   953.994240   959.336744   826.769674   948.984053
# S_cereus     1009.355124   976.507088  1018.901162   854.043597  1035.625131
# S_soda        918.871962   872.773848   910.756902   826.103400   937.388163
# S_vibrio      923.054280   892.084491   908.170566   806.156042   912.192605
# S_caldi       888.987203   862.194814   888.972217   832.265924   899.521206
# S_gardner     681.437932   643.039448   666.044196   604.080025   678.571385
# S_burkho     1164.087078  1013.233089  1020.971819   870.025848  1041.177445
# S_para       1013.233089  1079.424822  1021.298234   864.821015  1014.616495
# S_rhizobium  1020.971819  1021.298234  1170.869174   871.377750  1068.526166
# S_desulfo     870.025848   864.821015   871.377750  1030.372152   866.221565
# S_agro       1041.177445  1014.616495  1068.526166   866.221565  1176.554823

# %%
plt.pyplot.pcolor(a.values)
plt.pyplot.yticks(np.arange(0.5, len(S), 1), a.index)
plt.pyplot.xticks(np.arange(0.5, len(S), 1), a.index, rotation=90)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x000000000AE3AD88>

# %%
a.to_csv("analysis 20 bacteria/cca_matrix.csv")

# %% [markdown]
# ## 2) Jacard-index

# %%
def jacard_index(S1, S2):
    """
    @param S1: stoichiometric matrix not "equalized" with S2
    @param S2: stoichiometric matrix not "equalized" with S1
    @return: Jacard index
    
    MATH description..? => only counts the number of shared reactions
             |S1 ∩ S2|
    Jacard = ---------
             |S1 U S2|
    """
    reaction_intersect = S2.columns.isin(S1.columns).sum()
    reaction_different1 = S1.shape[1] - reaction_intersect
    reaction_different2 = S2.shape[1] - reaction_intersect
    
    jacard_index = reaction_intersect 
    union = (reaction_intersect + reaction_different1 + reaction_different2 + 0.)
    jacard_index /= union
    return jacard_index

def jacard_matrix(list_of_S):
    n = len(list_of_S)
    df_jm = np.zeros([n, n])
    for i in xrange(n):
        for j in xrange(n):
            S1 = eval(list_of_S[i])
            S2 = eval(list_of_S[j])
            df_jm[i,j] = jacard_index(S1, S2)
    return pd.DataFrame(df_jm, columns= list_of_S, index = list_of_S)

# %%
jm = jacard_matrix(S)

# %%
jm
# Out:
#              S_rhodo1   S_lacto  S_termite  S_rhodo2   S_deino  S_anthracis  \
# S_rhodo1     1.000000  0.535714   0.425658  0.595545  0.644556     0.562911
# S_lacto      0.535714  1.000000   0.408038  0.416532  0.554736     0.531730
# S_termite    0.425658  0.408038   1.000000  0.375467  0.407186     0.355754
# S_rhodo2     0.595545  0.416532   0.375467  1.000000  0.489955     0.476684
# S_deino      0.644556  0.554736   0.407186  0.489955  1.000000     0.540527
# S_anthracis  0.562911  0.531730   0.355754  0.476684  0.540527     1.000000
# S_bacillus   0.574353  0.522936   0.378146  0.461538  0.560631     0.627623
# S_flavo      0.495705  0.413742   0.340088  0.442576  0.485948     0.493800
# S_flavo      0.478455  0.404418   0.259756  0.474453  0.491195     0.502323
# S_glucono    0.506234  0.420759   0.217331  0.479444  0.510012     0.485778
# S_acineto    0.648313  0.486735   0.276097  0.660822  0.701683     0.647826
# S_cereus     0.585516  0.444544   0.294857  0.583096  0.594381     0.603365
# S_soda       0.594475  0.442372   0.276587  0.572791  0.544020     0.553793
# S_vibrio     1.000000  0.456954   0.286527  0.601399  0.598889     0.587420
# S_caldi      0.456954  1.000000   0.255006  0.463495  0.466602     0.467422
# S_gardner    0.286527  0.255006   1.000000  0.279807  0.284942     0.277644
# S_burkho     0.601399  0.463495   0.279807  1.000000  0.672912     0.647089
# S_para       0.598889  0.466602   0.284942  0.672912  1.000000     0.704471
# S_rhizobium  0.587420  0.467422   0.277644  0.647089  0.704471     1.000000
# S_desulfo    0.487831  0.463923   0.259889  0.480494  0.522584     0.494270
# S_agro       0.590593  0.471341   0.278379  0.669083  0.700599     0.742703
#
#              S_desulfo    S_agro
# S_rhodo1      0.507743  0.676705
# S_lacto       0.427174  0.514073
# S_termite     0.441694  0.394737
# S_rhodo2      0.469995  0.543579
# S_deino       0.474090  0.609661
# S_anthracis   0.460679  0.595069
# S_bacillus    0.489212  0.594905
# S_flavo       0.417256  0.502791
# S_glucono     0.485976  0.509070
# S_acineto     0.496000  0.644951
# S_cereus      0.446927  0.614044
# S_soda        0.461538  0.571500
# S_vibrio      0.487831  0.590593
# S_caldi       0.463923  0.471341
# S_gardner     0.259889  0.278379
# S_burkho      0.480494  0.669083
# S_para        0.522584  0.700599
# S_rhizobium   0.494270  0.742703
# S_desulfo     1.000000  0.477811
# S_agro        0.477811  1.000000

# %%
plt.pyplot.pcolor(b.values)
plt.pyplot.yticks(np.arange(0.5, len(S), 1), b.index)
plt.pyplot.xticks(np.arange(0.5, len(S), 1), b.index, rotation=90)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x000000000F55ED48>

# %% [markdown]
# ## 3) Comparison

# %%
f = gcf()  # f = figure(n) if you know the figure number
f.set_size_inches(11.69,8.27)

subplot(121, aspect = 'equal')
plt.pyplot.pcolor(a.values)
plt.pyplot.yticks(np.arange(0.5, len(S), 1), a.index)
plt.pyplot.xticks(np.arange(0.5, len(S), 1), a.index, rotation=90)
colorbar(fraction=0.046, pad=0.04)
plt.pyplot.title("CCA")

subplot(122, aspect = 'equal')
plt.pyplot.pcolor(b.values)
plt.pyplot.yticks(np.arange(0.5, len(S), 1), b.index)
plt.pyplot.xticks(np.arange(0.5, len(S), 1), b.index, rotation=90)
colorbar(fraction=0.046, pad=0.04)
plt.pyplot.title("Jacard Index")

plt.pyplot.tight_layout()

# %%
f = gcf()  # f = figure(n) if you know the figure number
f.set_size_inches(11.69,8.27)

subplot(121, aspect = 'equal')
plt.pyplot.pcolor(a.values)
plt.pyplot.yticks(np.arange(0.5, len(S), 1), a.index)
plt.pyplot.xticks(np.arange(0.5, len(S), 1), a.index, rotation=90)
colorbar(fraction=0.046, pad=0.04)
plt.pyplot.title("CCA")

subplot(122, aspect = 'equal')
plt.pyplot.pcolor(b.values)
plt.pyplot.yticks(np.arange(0.5, len(S), 1), b.index)
plt.pyplot.xticks(np.arange(0.5, len(S), 1), b.index, rotation=90)
colorbar(fraction=0.046, pad=0.04)
plt.pyplot.title("Jacard Index")

plt.pyplot.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0e33ef241b25> in <module>()
#      10
#      11 subplot(122, aspect = 'equal')
# ---> 12 plt.pyplot.pcolor(b.values)
#      13 plt.pyplot.yticks(np.arange(0.5, len(S), 1), b.index)
#      14 plt.pyplot.xticks(np.arange(0.5, len(S), 1), b.index, rotation=90)
#
# NameError: name 'b' is not defined
